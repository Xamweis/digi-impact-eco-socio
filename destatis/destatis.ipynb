# %%
import requests

# %%
with open("secrets.txt","r") as f:
    string = f.read()

IHRE_KENNUNG = string.split('\n')[1]
IHR_PASSWORT = string.split('\n')[3]

# %%
url = f'https://www-genesis.destatis.de/genesisWS/rest/2020/data/resultfile?username={IHRE_KENNUNG}&password={IHR_PASSWORT}&name=digitalisation&area=user&compress=false&format=csv&language=en'
res = requests.get(url)

# %%
import pandas as pd
from io import StringIO

# %%
pd.read_excel('digitalisation.xlsx')
# Out:
# /home/mabioo/anaconda3/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#     IKT-Indikatoren für Unternehmen: Deutschland, Jahre,\nWirtschaftszweige, Beschäftigtengrößenklassen  \
# 0    Nutzung v.Informations-u.Kommunikationstech.i....
# 1                                          Deutschland
# 2            IKT-Indikatoren für Unternehmen (Prozent)
# 3                     Jahr\nWZ2008 (Abschnitte): IKT\n
# 4                                                  NaN
# ..                                                 ...
# 395                                                NaN
# 396                                                NaN
# 397                                     ______________
# 398                                                NaN
# 399  © Statistisches Bundesamt (Destatis), 2023 | S...
#
# ...

# %%
string_repr = res.content.decode()
string_repr = string_repr[string_repr.find('ICT indicators for enterprises (percent)'):]
# string_repr
# with open('test.csv', 'w') as f:
#     f.write(string_repr)

# %%
l = StringIO(string_repr)
pd.read_csv(l, delimiter=";")
# Out:
#          ICT indicators for enterprises (percent)     Unnamed: 1  \
# 0                                             NaN            NaN
# 1                                             NaN            NaN
# 2                                            2015            NaN
# 3                                          WZ08-C  Manufacturing
# 4                                             NaN            NaN
# ..                                            ...            ...
# 392                                           NaN            NaN
# 393                                           NaN            NaN
# 394                                    __________            NaN
# 395  © Federal Statistical Office, Wiesbaden 2023            NaN
# 396                created: 2023-01-26 / 14:36:44            NaN
#
#                        Unnamed: 2  Unnamed: 3  \
# 0                             NaN  Use of ICT
# 1                             NaN   Computers
# ...

# %%
import requests

url = "https://apidojo-yahoo-finance-v1.p.rapidapi.com/auto-complete"

querystring = {"q":"tesla","region":"US"}

headers = {
	"X-RapidAPI-Key": "36ec980bcbmshe700420eefee90ap1601c7jsn750ce5280f1f",
	"X-RapidAPI-Host": "apidojo-yahoo-finance-v1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"message":"You are not subscribed to this API."}
